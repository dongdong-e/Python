# %%
import pandas as pd
import numpy as np

# %%
players = pd.read_csv('df_set_1617.csv')
son_ratings = pd.read_csv('Son_1617_ratings_df.csv')

# %%
players.head()
# Out:
#    Goal       Member           Member.1           Member.2           Member.3  \
# 0   NaN            1                  2                  3                  4
# 1   7.0  Hugo Lloris  Toby Alderweireld     Jan Vertonghen    Kieran Trippier
# 2   6.0  Hugo Lloris     Jan Vertonghen  Toby Alderweireld          Eric Dier
# 3   2.0  Hugo Lloris     Jan Vertonghen         Ben Davies  Toby Alderweireld
# 4   0.0  Hugo Lloris  Toby Alderweireld         Ben Davies        Kyle Walker
#
#           Member.4           Member.5       Member.6           Member.7  \
# 0                5                  6              7                  8
# 1       Ben Davies  Christian Eriksen      Eric Dier      Son Heung-Min
# 2    Mousa Dembele     Victor Wanyama     Ben Davies     Moussa Sissoko
# 3  Kieran Trippier          Dele Alli  Son Heung-Min  Christian Eriksen
# 4   Jan Vertonghen  Christian Eriksen      Dele Alli     Victor Wanyama
#
# ...

# %%
players = players.iloc[1:, 0:12]
players = players[players.values == 'Son Heung-Min']
players = players.reset_index()
players = players.drop('index', axis = 1)

# %%
players['Rating'] = son_ratings['Rating']
players
# Out:
#     Goal       Member           Member.1           Member.2  \
# 0    6.0  Hugo Lloris     Jan Vertonghen  Toby Alderweireld
# 1    2.0  Hugo Lloris     Jan Vertonghen         Ben Davies
# 2    0.0  Hugo Lloris  Toby Alderweireld         Ben Davies
# 3    2.0  Hugo Lloris  Toby Alderweireld         Ben Davies
# 4    4.0  Hugo Lloris        Kyle Walker  Toby Alderweireld
# 5    4.0  Hugo Lloris    Kieran Trippier     Jan Vertonghen
# 6    3.0  Michel Vorm  Toby Alderweireld     Jan Vertonghen
# 7    2.0  Hugo Lloris  Toby Alderweireld     Jan Vertonghen
# 8    0.0  Hugo Lloris          Eric Dier  Toby Alderweireld
# 9    1.0  Hugo Lloris          Eric Dier         Ben Davies
# 10   0.0  Michel Vorm        Kyle Walker  Toby Alderweireld
# 11   4.0  Hugo Lloris       Kevin Wimmer  Toby Alderweireld
# 12   0.0  Hugo Lloris     Jan Vertonghen        Kyle Walker
# 13   5.0  Hugo Lloris          Eric Dier         Danny Rose
# 14   1.0  Hugo Lloris       Kevin Wimmer     Jan Vertonghen
# ...

# %%
players.to_csv("players_with_son_1617.csv", index=False)
