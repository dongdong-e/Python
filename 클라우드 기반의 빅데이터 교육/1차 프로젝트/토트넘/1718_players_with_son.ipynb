# %%
import pandas as pd
import numpy as np

# %%
players = pd.read_csv('df_set_1718.csv')
son_ratings = pd.read_csv('Son_1718_ratings_df.csv')

# %%
players.head()
# Out:
#    Goal       Member           Member.1            Member.2         Member.3  \
# 0   NaN            1                  2                   3                4
# 1   4.0  Hugo Lloris          Eric Dier  Kyle Walker-Peters       Danny Rose
# 2   1.0  Hugo Lloris   Davinson Sanchez     Kieran Trippier   Jan Vertonghen
# 3   0.0  Hugo Lloris  Toby Alderweireld    Davinson Sanchez   Jan Vertonghen
# 4   2.0  Hugo Lloris   Davinson Sanchez      Jan Vertonghen  Kieran Trippier
#
#             Member.4           Member.5           Member.6         Member.7  \
# 0                  5                  6                  7                8
# 1  Toby Alderweireld     Victor Wanyama        Erik Lamela      Lucas Moura
# 2         Ben Davies  Christian Eriksen          Dele Alli   Victor Wanyama
# 3  Christian Eriksen     Victor Wanyama         Danny Rose  Kieran Trippier
# 4         Ben Davies          Eric Dier  Christian Eriksen    Son Heung-Min
#
# ...

# %%
players = players.iloc[1:, 0:12]
players = players[players.values == 'Son Heung-Min']
players = players.reset_index()
players = players.drop('index', axis = 1)

# %%
players['Rating'] = son_ratings['Rating']
players = players.fillna(7)
players
# Out:
#     Goal           Member           Member.1           Member.2  \
# 0    1.0      Hugo Lloris   Davinson Sanchez    Kieran Trippier
# 1    2.0      Hugo Lloris   Davinson Sanchez     Jan Vertonghen
# 2    1.0      Hugo Lloris       Serge Aurier         Ben Davies
# 3    2.0      Hugo Lloris         Danny Rose     Jan Vertonghen
# 4    3.0      Hugo Lloris    Kieran Trippier         Ben Davies
# 5    4.0      Hugo Lloris         Danny Rose     Jan Vertonghen
# 6    2.0      Hugo Lloris       Serge Aurier         Ben Davies
# 7    1.0      Hugo Lloris   Davinson Sanchez     Jan Vertonghen
# 8    2.0      Hugo Lloris     Jan Vertonghen    Kieran Trippier
# 9    1.0      Hugo Lloris     Jan Vertonghen         Ben Davies
# 10   1.0      Michel Vorm   Davinson Sanchez       Serge Aurier
# 11   4.0      Hugo Lloris       Serge Aurier         Ben Davies
# 12   1.0      Hugo Lloris       Serge Aurier         Ben Davies
# 13   2.0      Hugo Lloris   Davinson Sanchez         Ben Davies
# ...

# %%
players.to_csv("players_with_son_1718.csv", index=False)
