# %%
# xlsx to csv

import xlrd
import csv
import pandas as pd

def csv_from_excel():
    wb = xlrd.open_workbook('test_합본.xlsx')
    sh = wb.sheet_by_name('test')
    your_csv_file = open('test.csv', 'w')
    wr = csv.writer(your_csv_file, quoting=csv.QUOTE_ALL)

    for rownum in range(sh.nrows):
        wr.writerow(sh.row_values(rownum))

    your_csv_file.close()

# runs the csv_from_excel function:
csv_from_excel()

# %%
test_1 = pd.read_csv('test.csv', encoding='utf-8')
test_1.head()
# Out:
#         명칭     소속   왕(인물)   왕(시기)      유형       분류 행정 구     연도  \
# 0  지광국사현묘탑    경복궁  문종(고려)  문종(고려)      승탑       국보  종로구  1075년
# 1      홍화문    창경궁      성종     광해군  궁궐, 궁문       보물  종로구  1484년
# 2   창녕위궁재사     무덤      순조      순조  건축, 재사    등록문화재  강북구  1832년
# 3       후원    창덕궁      태종      태종  유적, 정원       사적  종로구  1405년
# 4   창빈안씨묘역  국립현충원      숙종      선조       묘  시도유형문화재  동작구  1683년
#
#                                                  설명1  \
# 0  1962년 12월 20일 국보 제101호로 지정되었다. 전체 높이는 6.1m이다. ...
# 1  보물 제384호. 우진각지붕집. 정면 3칸, 측면 2칸의 다포계 중층 문루. 148...
# 2  조선 제23대 순조의 둘째 딸 복온공주(福溫公主:1818~1832)와 부마 창녕위(...
# 3  면적 10만 3000여 평. 사적 제122호로 지정된 창덕궁 안에 있는 조선시대 정...
# 4  1983년에 서울시유형문화재 제54호로 지정되었다. 조선 제11대 중종의 후궁(後宮...
#
#                                                  설명2
# 0  지광국사탑은 고려시대 조정이 최고의 승려에게 내리는 법계인 ‘국사’(國師)를 받은 ...
# 1  정면 3칸, 측면 2칸의 중층(2층) 우진각지붕으로 동쪽으로 향한 점이 특징인 대문...
# 2  1832년에 복온공주가 세상을 떠난 뒤 무덤이 주변에 자리하였고, 이어서 김병주의 ...
# ...

# %%
import googlemaps
gmaps_key = "AIzaSyAxDKNtZfZJ387lEm7qoMQDQhVAjzqEKLs"
gmaps = googlemaps.Client(key = gmaps_key)

# %%
test_1['소속'].unique()
# Out:
# array(['경복궁', '창경궁', '무덤', '창덕궁', '국립현충원', '사찰', '종묘', '릉', '경희궁', '북한산성',
#        '덕수궁', '박물관', '전쟁기념관', '서울역사박물관', '서울시', '어린이대공원'], dtype=object)

# %%
# 이나럼ㄴ아ㅣㅅ홈ㅇ뤼홈ㄴ우ㅏㅣㅎ넘ㄹㄴㅁ어린무ㅡㅌ 

# delete = ['무덤', '사찰', '릉', '박물관', '서울시']


# for i in range(0, len(test_1)):
#     for j in test_1['소속'].unique():
#         if j in delete:
#             test_1['주소'][i] = 'asdf'
        
#         else:
#             x = gmaps.geocode(j, language = 'ko')
#             test_1['주소'][i] = x[0].get('formatted_address')

# %%
delete = ['무덤', '사찰', '릉', '박물관', '서울시']

for i in range(0, len(test_1)):
    
    if test_1['소속'][i] in delete:
        test_1['주소'][i] = np.nan
        
    else :
        j = test_1['소속'][i]
        x = gmaps.geocode(j, language = 'ko')
        test_1['주소'][i] = x[0].get('formatted_address')

# %%
test_1.head()
# Out:
#         명칭     소속   왕(인물)   왕(시기)      유형       분류 행정 구     연도  \
# 0  지광국사현묘탑    경복궁  문종(고려)  문종(고려)      승탑       국보  종로구  1075년
# 1      홍화문    창경궁      성종     광해군  궁궐, 궁문       보물  종로구  1484년
# 2   창녕위궁재사     무덤      순조      순조  건축, 재사    등록문화재  강북구  1832년
# 3       후원    창덕궁      태종      태종  유적, 정원       사적  종로구  1405년
# 4   창빈안씨묘역  국립현충원      숙종      선조       묘  시도유형문화재  동작구  1683년
#
#                                                  설명1  \
# 0  1962년 12월 20일 국보 제101호로 지정되었다. 전체 높이는 6.1m이다. ...
# 1  보물 제384호. 우진각지붕집. 정면 3칸, 측면 2칸의 다포계 중층 문루. 148...
# 2  조선 제23대 순조의 둘째 딸 복온공주(福溫公主:1818~1832)와 부마 창녕위(...
# 3  면적 10만 3000여 평. 사적 제122호로 지정된 창덕궁 안에 있는 조선시대 정...
# 4  1983년에 서울시유형문화재 제54호로 지정되었다. 조선 제11대 중종의 후궁(後宮...
#
#                                                  설명2  \
# 0  지광국사탑은 고려시대 조정이 최고의 승려에게 내리는 법계인 ‘국사’(國師)를 받은 ...
# 1  정면 3칸, 측면 2칸의 중층(2층) 우진각지붕으로 동쪽으로 향한 점이 특징인 대문...
# 2  1832년에 복온공주가 세상을 떠난 뒤 무덤이 주변에 자리하였고, 이어서 김병주의 ...
# ...

# %%
test_1['주소'].isnull().sum()
# Out:
# 40

# %%
test_1.to_excel('filename.xlsx', index= False)

# %% [markdown]
# ---

# %%
# xlsx to csv

import xlrd
import csv
import pandas as pd

def csv_from_excel():
    wb = xlrd.open_workbook('유적지_주소_추가.xlsx')
    sh = wb.sheet_by_name('Sheet1')
    your_csv_file = open('hist_location.csv', 'w')
    wr = csv.writer(your_csv_file, quoting=csv.QUOTE_ALL)

    for rownum in range(sh.nrows):
        wr.writerow(sh.row_values(rownum))

    your_csv_file.close()

# runs the csv_from_excel function:
csv_from_excel()

# %%
df = pd.read_csv('hist_location.csv', encoding = 'utf-8')

# %%
hist_lat = []
hist_lng = []

for addr in df['주소']:
    tmp = gmaps.geocode(addr, language = 'ko')
    
    # 위의 코드에서 'geometry'가 가지고 데이터('location'의 'lat', 'lng')를 모두 가져옴
    tmp_loc = tmp[0].get('geometry')
    
    # tmp_loc에 있는 'location'에서 'lat' 위도 데이터를 가져옴
    hist_lat.append(tmp_loc['location']['lat'])
    
    # tmp_loc에 있는 'location'에서 'lng' 경도 데이터를 가져옴
    hist_lng.append(tmp_loc['location']['lng'])

# %%
df['위도'] = hist_lat
df['경도'] = hist_lng

# %%
folium.GeoJson?

# %%
df
# Out:
#              명칭      소속     왕(인물)     왕(시기)        유형         분류   행정구  \
# 0       지광국사현묘탑     경복궁    문종(고려)    문종(고려)        승탑         국보   종로구
# 1           홍화문     창경궁        성종       광해군    궁궐, 궁문         보물   종로구
# 2        창녕위궁재사      무덤        순조        순조    건축, 재사      등록문화재   강북구
# 3            후원     창덕궁        태종        태종    유적, 정원         사적   종로구
# 4        창빈안씨묘역   국립현충원        숙종        선조         묘    시도유형문화재   동작구
# 5    천상열차분야지도각석     경복궁        태조        태조   천문도, 지도         보물    중구
# 6           천추전     경복궁        태조        고종        건축         사적   종로구
# 7           청권사      사찰        영조        영조    사당, 묘소      유형문화재   서초구
# 8    초안산조선시대분묘군      무덤        인조        인조         묘         사적   노원구
# 9      충숙공이상길묘역      무덤        인조        인조        석비    시도유형문화재   노원구
# 10      충헌공김구묘역      무덤        숙종        영조        석비    시도유형문화재   송파구
# 11          칠사당      종묘        조선        태조        사당  유네스코 세계유산   종로구
# ...

# %%
style = {'fillColor': 'red', 'lineColor': 'black'}

# %%
geo_path = 'seoul_municipalities_geo_simple.json'
geo_json = json.load(open(geo_path, encoding = 'utf-8'))

map = folium.Map(location = [df['위도'].mean(), df['경도'].mean()], zoom_start = 11)

for n in df.index:
    folium.Marker([df['위도'][n],
                  df['경도'][n]],
                  popup = df['명칭'][n],
                 icon = folium.Icon(color = 'gray')).add_to(map)
    
folium.GeoJson(geo_path, style_function = lambda x: style).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
geo_path = 'seoul_municipalities_geo_simple.json'
geo_json = json.load(open(geo_path, encoding = 'utf-8'))

map = folium.Map(location = [df['위도'].mean(), df['경도'].mean()], zoom_start = 11)

for n in df.index:
    folium.Marker([df['위도'][n],
                  df['경도'][n]],
                  popup = df['명칭'][n],
                 icon = folium.Icon(color = 'gray')).add_to(map)
    
folium.GeoJson(geo_path).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium
import json

geo_path = 'seoul_municipalities_geo_simple.json'
geo_json = json.load(open(geo_path, encoding = 'utf-8'))

map = folium.Map(location = [df['위도'].mean(), df['경도'].mean()], zoom_start = 11)

for n in df.index:
    folium.Marker([df['위도'][n],
                  df['경도'][n]],
                  popup = df['명칭'][n],
                 icon = folium.Icon(color = 'blue')).add_to(map)
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Out:
# 'seoul_municipalities_geo_simple.json'
